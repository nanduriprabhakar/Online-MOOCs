# %%
import pandas as pd

# %%
raw_file=pd.read_excel("salary_data.xlsx",index_col='order')

# %%
raw_file
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# order
# 1       I-200-14073-248840               denied          3/14/2014
# 2            A-15061-55212               denied          3/19/2015
# 3       I-200-13256-001092               denied          9/13/2013
# 4       I-200-14087-353657               denied          3/28/2014
# 5       I-203-14259-128844               denied          9/16/2014
# 6       I-200-14092-483272               denied           4/2/2014
# 7       I-200-13084-487292               denied          3/25/2013
# 8       I-200-13126-805026               denied           5/6/2013
# 9       I-200-13128-133480               denied          5/10/2013
# 10      I-200-14069-400950               denied          3/10/2014
# 11      I-200-11332-593285               denied         11/28/2011
# 12      I-200-14093-494144               denied           4/3/2014
# 13      I-200-11172-152960  certified-withdrawn          6/21/2011
# ...
